# %% [markdown]
# <a href="https://colab.research.google.com/github/yeop94/2022--AI_Dnue/blob/main/20221129_%EB%8C%80%ED%95%99%EC%9B%90%EC%88%98%EC%97%85_Perceptron2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 데이터에 라벨이 다 붙어있으므로 지도학습임.
# ### single perceptron ---> input layer - hidden layer - output layer
# ### dot product(두 점의 곱, 내적)

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

print("[PerceptronClassifier-03-Compute:#1] (Perceptron Classifier) Read Data >> ")
input()
      # [x1Val, x2Val, Label]
Dat = [ [-8,1,'B'],  [-6,-1,'B'], [-5,-3,'B'], [-5,3,'B'], [-3,-2,'B'],
        [-2,-1,'B'], [-2,2,'B'],  [0,-3,'B'],  [2,-2,'B'], [3,7,'A'],
        [4,-4,'B'],  [4,9,'A'],   [6,4,'A'],   [6,8,'A'],  [7,-1,'A'],
        [8,2,'A'],   [9,4,'A'],   [10,-5,'A'], [12,1,'A'], [13,3,'A']
      ]



#Wa,Wb,Wc = input(("input weights(Wa,Wb,Wc)(e.g.,0, 1, 0.5) >>"    )).split()
#Wa = float(Wa)
#Wb = float(Wb)
#Wc = float(Wc)

Wa = 0
Wb = 1
Wc = 0.5


print("Weights >>","Wa=",Wa,"Wb=",Wb,"Wc=",Wc)
    # slope -->  x2 = -w1/w3*x1 - w1/w3

slope = -(Wb/Wc)          # -2
intercept = -(Wa/Wc)      # 0
   #test; (-8,1)
#x1 = -8
#x2 = slope*x1 + intercept   # 16
print("slope =",round(slope,1),",intercept = ",intercept)
input()

L = 0.2      # Learning rate

while(1):

  print("Now, Classifying...")
  nErr = 0     # nbr of error
  iter = 0     # iter count

  for D in Dat:
    iter += 1
    x1 = D[0]   # = x1Val
    x2Val = D[1]
    x2 = slope*x1+intercept      #e.g..; x1 = -8, x2 = 16 (x2Val = 1)
    print("x1 = ",x1,",x2Val = ",x2Val,",x2 = ",x2)
    if (x2Val > x2):
      group = 'A'
    else :
      group = 'B'
  
    print("group = ",group)

    if (group != D[2]):      #error occurs
      print("Current Data =",D,"computed group = ",group,"real group =",D[2])
      nErr += 1
      if (nErr == 1):  #first error
        firstE = iter - 1



    if (group == 'A'):
        dVal = -1
    else:
        dVal = 1

  print("dVal = ",dVal)

  if nErr == 0 :
    break
    
  x1Dat = Dat[firstE][0]  # (2,-2)   --> x1 = 2
  x2Dat = Dat[firstE][1]  # (2,-2)   --> x2 = -2
  Wa = Wa + L*dVal*1
  Wb = Wb + L*dVal*x1Dat
  Wc = Wc + L*dVal*x2Dat

  slope = -(Wb/Wc)          
  intercept = -(Wa/Wc)  
  print("Weights >>","Wa=",Wa,"Wb=",Wb,"Wc=",Wc)
  print("slope =",round(slope,2),",intercept = ",round(intercept,2))

  x2 = slope*x1Dat + intercept
  print("x2 = ",round(x2,2))


print("================== Result ===============")
print("slope = ",round(slope,2),"intercept = ",round(intercept,2))

print("###########  END OF PROGRAM   ############")

#//
# Out:
# [PerceptronClassifier-03-Compute:#1] (Perceptron Classifier) Read Data >>
#
# Weights >> Wa= 0 Wb= 1 Wc= 0.5
# slope = -2.0 ,intercept =  -0.0
#
# Now, Classifying...
# x1 =  -8 ,x2Val =  1 ,x2 =  16.0
# group =  B
# x1 =  -6 ,x2Val =  -1 ,x2 =  12.0
# group =  B
# x1 =  -5 ,x2Val =  -3 ,x2 =  10.0
# group =  B
# x1 =  -5 ,x2Val =  3 ,x2 =  10.0
# group =  B
# x1 =  -3 ,x2Val =  -2 ,x2 =  6.0
# group =  B
# x1 =  -2 ,x2Val =  -1 ,x2 =  4.0
# group =  B
# x1 =  -2 ,x2Val =  2 ,x2 =  4.0
# group =  B
# x1 =  0 ,x2Val =  -3 ,x2 =  -0.0
# group =  B
# x1 =  2 ,x2Val =  -2 ,x2 =  -4.0
# group =  A
# Current Data = [2, -2, 'B'] computed group =  A real group = B
# x1 =  3 ,x2Val =  7 ,x2 =  -6.0
# group =  A
# x1 =  4 ,x2Val =  -4 ,x2 =  -8.0
# group =  A
# Current Data = [4, -4, 'B'] computed group =  A real group = B
# x1 =  4 ,x2Val =  9 ,x2 =  -8.0
# group =  A
# x1 =  6 ,x2Val =  4 ,x2 =  -12.0
# group =  A
# x1 =  6 ,x2Val =  8 ,x2 =  -12.0
# group =  A
# x1 =  7 ,x2Val =  -1 ,x2 =  -14.0
# group =  A
# x1 =  8 ,x2Val =  2 ,x2 =  -16.0
# group =  A
# x1 =  9 ,x2Val =  4 ,x2 =  -18.0
# group =  A
# x1 =  10 ,x2Val =  -5 ,x2 =  -20.0
# group =  A
# x1 =  12 ,x2Val =  1 ,x2 =  -24.0
# group =  A
# x1 =  13 ,x2Val =  3 ,x2 =  -26.0
# group =  A
# dVal =  -1
# Weights >> Wa= -0.2 Wb= 0.6 Wc= 0.9
# slope = -0.67 ,intercept =  0.22
# x2 =  -1.11
# Now, Classifying...
# x1 =  -8 ,x2Val =  1 ,x2 =  5.555555555555555
# group =  B
# x1 =  -6 ,x2Val =  -1 ,x2 =  4.222222222222222
# group =  B
# x1 =  -5 ,x2Val =  -3 ,x2 =  3.5555555555555554
# group =  B
# x1 =  -5 ,x2Val =  3 ,x2 =  3.5555555555555554
# group =  B
# x1 =  -3 ,x2Val =  -2 ,x2 =  2.2222222222222223
# group =  B
# x1 =  -2 ,x2Val =  -1 ,x2 =  1.5555555555555556
# group =  B
# x1 =  -2 ,x2Val =  2 ,x2 =  1.5555555555555556
# group =  A
# Current Data = [-2, 2, 'B'] computed group =  A real group = B
# x1 =  0 ,x2Val =  -3 ,x2 =  0.22222222222222224
# group =  B
# x1 =  2 ,x2Val =  -2 ,x2 =  -1.111111111111111
# group =  B
# x1 =  3 ,x2Val =  7 ,x2 =  -1.7777777777777777
# group =  A
# x1 =  4 ,x2Val =  -4 ,x2 =  -2.444444444444444
# group =  B
# x1 =  4 ,x2Val =  9 ,x2 =  -2.444444444444444
# group =  A
# x1 =  6 ,x2Val =  4 ,x2 =  -3.7777777777777777
# group =  A
# x1 =  6 ,x2Val =  8 ,x2 =  -3.7777777777777777
# group =  A
# x1 =  7 ,x2Val =  -1 ,x2 =  -4.444444444444444
# group =  A
# x1 =  8 ,x2Val =  2 ,x2 =  -5.111111111111111
# group =  A
# x1 =  9 ,x2Val =  4 ,x2 =  -5.777777777777778
# group =  A
# x1 =  10 ,x2Val =  -5 ,x2 =  -6.444444444444444
# group =  A
# x1 =  12 ,x2Val =  1 ,x2 =  -7.777777777777778
# group =  A
# x1 =  13 ,x2Val =  3 ,x2 =  -8.444444444444445
# group =  A
# dVal =  -1
# Weights >> Wa= -0.4 Wb= 1.0 Wc= 0.5
# slope = -2.0 ,intercept =  0.8
# x2 =  4.8
# Now, Classifying...
# x1 =  -8 ,x2Val =  1 ,x2 =  16.8
# group =  B
# x1 =  -6 ,x2Val =  -1 ,x2 =  12.8
# group =  B
# x1 =  -5 ,x2Val =  -3 ,x2 =  10.8
# group =  B
# x1 =  -5 ,x2Val =  3 ,x2 =  10.8
# group =  B
# x1 =  -3 ,x2Val =  -2 ,x2 =  6.8
# group =  B
# x1 =  -2 ,x2Val =  -1 ,x2 =  4.8
# group =  B
# x1 =  -2 ,x2Val =  2 ,x2 =  4.8
# group =  B
# x1 =  0 ,x2Val =  -3 ,x2 =  0.8
# group =  B
# x1 =  2 ,x2Val =  -2 ,x2 =  -3.2
# group =  A
# Current Data = [2, -2, 'B'] computed group =  A real group = B
# x1 =  3 ,x2Val =  7 ,x2 =  -5.2
# group =  A
# x1 =  4 ,x2Val =  -4 ,x2 =  -7.2
# group =  A
# Current Data = [4, -4, 'B'] computed group =  A real group = B
# x1 =  4 ,x2Val =  9 ,x2 =  -7.2
# group =  A
# x1 =  6 ,x2Val =  4 ,x2 =  -11.2
# group =  A
# x1 =  6 ,x2Val =  8 ,x2 =  -11.2
# group =  A
# x1 =  7 ,x2Val =  -1 ,x2 =  -13.2
# group =  A
# x1 =  8 ,x2Val =  2 ,x2 =  -15.2
# group =  A
# x1 =  9 ,x2Val =  4 ,x2 =  -17.2
# group =  A
# x1 =  10 ,x2Val =  -5 ,x2 =  -19.2
# group =  A
# x1 =  12 ,x2Val =  1 ,x2 =  -23.2
# group =  A
# x1 =  13 ,x2Val =  3 ,x2 =  -25.2
# group =  A
# dVal =  -1
# Weights >> Wa= -0.6000000000000001 Wb= 0.6 Wc= 0.9
# slope = -0.67 ,intercept =  0.67
# x2 =  -0.67
# Now, Classifying...
# x1 =  -8 ,x2Val =  1 ,x2 =  6.0
# group =  B
# x1 =  -6 ,x2Val =  -1 ,x2 =  4.666666666666667
# group =  B
# x1 =  -5 ,x2Val =  -3 ,x2 =  4.0
# group =  B
# x1 =  -5 ,x2Val =  3 ,x2 =  4.0
# group =  B
# x1 =  -3 ,x2Val =  -2 ,x2 =  2.666666666666667
# group =  B
# x1 =  -2 ,x2Val =  -1 ,x2 =  2.0
# group =  B
# x1 =  -2 ,x2Val =  2 ,x2 =  2.0
# group =  B
# x1 =  0 ,x2Val =  -3 ,x2 =  0.6666666666666667
# group =  B
# x1 =  2 ,x2Val =  -2 ,x2 =  -0.6666666666666665
# group =  B
# x1 =  3 ,x2Val =  7 ,x2 =  -1.3333333333333333
# group =  A
# x1 =  4 ,x2Val =  -4 ,x2 =  -1.9999999999999998
# group =  B
# x1 =  4 ,x2Val =  9 ,x2 =  -1.9999999999999998
# group =  A
# x1 =  6 ,x2Val =  4 ,x2 =  -3.333333333333333
# group =  A
# x1 =  6 ,x2Val =  8 ,x2 =  -3.333333333333333
# group =  A
# x1 =  7 ,x2Val =  -1 ,x2 =  -3.999999999999999
# group =  A
# x1 =  8 ,x2Val =  2 ,x2 =  -4.666666666666666
# group =  A
# x1 =  9 ,x2Val =  4 ,x2 =  -5.333333333333333
# group =  A
# x1 =  10 ,x2Val =  -5 ,x2 =  -5.999999999999999
# group =  A
# x1 =  12 ,x2Val =  1 ,x2 =  -7.333333333333333
# group =  A
# x1 =  13 ,x2Val =  3 ,x2 =  -7.999999999999999
# group =  A
# dVal =  -1
# ================== Result ===============
# slope =  -0.67 intercept =  0.67
# ###########  END OF PROGRAM   ############
