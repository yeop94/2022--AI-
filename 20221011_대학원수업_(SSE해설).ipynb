# %% [markdown]
# <a href="https://colab.research.google.com/github/yeop94/2022--AI-/blob/main/20221011_%EB%8C%80%ED%95%99%EC%9B%90%EC%88%98%EC%97%85_(SSE%ED%95%B4%EC%84%A4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SSE해설

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@

print("[LR-04-SSE.py] SSE >> ")
# compute sum of squares of errors

import numpy as np

#====================  SHOW_2Dim()  =====================
def SHOW_2Dim(List):  
    for L in List:        #e.g., L=[-13.6470,-22.8235]
         out=[]
         for D in L:      #e.g., [D=-13.6470, D=-22.8235]
             out.append(round(D,3))  #e.g., [-13.647,-22.824]
         #for.D
         print(out)
    #for.L
#show_2dim()

def SSE(Dat,slope):
# sse = SSE(DatN,a)
  Num = len(Dat)
  sse=0
  for i in range(0,Num):
    # error for Dat[i]
    datX = Dat[i][0]
    datY = Dat[i][1]
    error = (slope*datX-datY)**2 
    sse += error
  #for.i
  return sse
#def.sse()

##################  Main  ########################

        # Height, Weight Data; 17
Dat = [ [150,42], [153,51], [155,62], [157,50], [157,76],
        [159,45], [161,72], [162,56], [164,65], [166,50],
        [166,72], [168,75], [169,82], [170,63], [172,73],
        [176,88], [177,80]
      ]  
                     # 02-NormalizeData
Num = len(Dat)

    # (Xa, Ya); average pt 
Xsum = 0
Ysum = 0

for j in range(0,Num):   # j=0,1,2,...,Num-1
    Xsum += Dat[j][0]
    Ysum += Dat[j][1]
#for.j

Xavg = Xsum / Num    # 163.5
Yavg = Ysum / Num    # 64.8
print("Xavg=",round(Xavg,1),"  Yavg=",round(Yavg,1))
input()

DatN = np.zeros((17,2))   # init.DatN to zeros

for j in range(0,Num):
    DatN[j][0] = Dat[j][0]-Xavg
    DatN[j][1] = Dat[j][1]-Yavg
#for.j
#print("DatN[]=",DatN)
print("DatN[]=")
SHOW_2Dim(DatN)
input()
                       # 03-slope
 # four areas; area1(+,+), area2(-,+), area3(-,-), area4(+,-)
 #             Ans; 7,2,6,2
area1=0
area2=0
area3=0
area4=0
for i in range(0,Num):
  #print("for.i=",i," DatN[i]=",DatN[i])
  if (DatN[i][0]>=0 and DatN[i][1]>=0):
     area1 += 1
  elif (DatN[i][0]<0 and DatN[i][1]>=0):
     area2 += 1
  elif (DatN[i][0]<0 and DatN[i][1]<0):
     area3 += 1
  else:
     area4 += 1
  #if
  #print("Number of data pts of Areas; [",area1,area2,area3,area4,"]")  # 7,2,6,2
  #input()
#for.i
              # Compute slope a; a=1 or a=-1
if (area1+area3) > (area2+area4) :      # 13 > 4  ->  a=1
   a=1
else:
   a=-1
#if
print("slope: a=",a)        # Ans; a=1
input()

    #04-SSE 
  # error for DatN[0]
datX = DatN[0][0]
datY = DatN[0][1]
error = (a*datX-datY)**2 
print("SSE for DatN[0]=",round(error,1))
input()
#0th row; (datX,datY)=(-13.6, -22.8)
#error = (a*(-13.6)-(-22.8))**2 -> (-13.6+22.8)**2  ->  9.2*9.2 = 84.2 

  # call SSE
sse = SSE(DatN,a)
print("Result; sse=",round(sse,1))     # 1570.5
input()



#05-Change slope
  # change slope both ways; to increase & decrease
delta = 0.01
if (SSE(DatN,(a+delta)) < sse) :
  delta = 0.01

else :
  delta = -0.01

print(";; delta = ", delta)    # delta = 0.01


#a1 = a + delta
#a2 = a - delta              # 여기서 a + 델타인지 a - 델타인지 의미없고 델타값만 마이너스로 바꿔주면됨.
#sse1 = SSE(DatN,a1)
#sse2 = SSE(DatN,a2)
#print("[05] Change slope; a1=",a1," sse1=",round(sse1,1))
#print("      Change slope; a2=",a2," sse2=",round(sse2,1))
#input()

 # to find min SSE
sseOld = SSE(DatN,a) 
while (1):
  a += delta
  sse = SSE(DatN,a)
  print("slope; a =",a," sse=",round(sse,1))
  #input()
  if (sse > sseOld) :   # terminal condition
    min_sse = sseOld
    a -= delta
    break # exit
  sseOld = sse
  print(" ; sseOld =",round(sseOld,1))
  

    #while
print("Out of while: slope =",round(a,2),"min_sse = ",round(min_sse,1))
 

#############  Result; slope=1.26, min SSE= 1499.8 



print("###############  End of Program  ################")
# Out:
# [LR-04-SSE.py] SSE >>
# Xavg= 163.6   Yavg= 64.8
#
# DatN[]=
# [-13.647, -22.824]
# [-10.647, -13.824]
# [-8.647, -2.824]
# [-6.647, -14.824]
# [-6.647, 11.176]
# [-4.647, -19.824]
# [-2.647, 7.176]
# [-1.647, -8.824]
# [0.353, 0.176]
# [2.353, -14.824]
# [2.353, 7.176]
# [4.353, 10.176]
# [5.353, 17.176]
# [6.353, -1.824]
# [8.353, 8.176]
# [12.353, 23.176]
# [13.353, 15.176]
#
# slope: a= 1
#
# SSE for DatN[0]= 84.2
#
# Result; sse= 1570.5
#
# ;; delta =  0.01
# slope; a = 1.01  sse= 1565.3
#  ; sseOld = 1565.3
# slope; a = 1.02  sse= 1560.3
#  ; sseOld = 1560.3
# slope; a = 1.03  sse= 1555.5
#  ; sseOld = 1555.5
# slope; a = 1.04  sse= 1550.9
#  ; sseOld = 1550.9
# slope; a = 1.05  sse= 1546.4
#  ; sseOld = 1546.4
# slope; a = 1.06  sse= 1542.2
#  ; sseOld = 1542.2
# slope; a = 1.07  sse= 1538.2
#  ; sseOld = 1538.2
# slope; a = 1.08  sse= 1534.4
#  ; sseOld = 1534.4
# slope; a = 1.09  sse= 1530.8
#  ; sseOld = 1530.8
# slope; a = 1.1  sse= 1527.4
#  ; sseOld = 1527.4
# slope; a = 1.11  sse= 1524.2
#  ; sseOld = 1524.2
# slope; a = 1.12  sse= 1521.2
#  ; sseOld = 1521.2
# slope; a = 1.1300000000000001  sse= 1518.4
#  ; sseOld = 1518.4
# slope; a = 1.1400000000000001  sse= 1515.7
#  ; sseOld = 1515.7
# slope; a = 1.1500000000000001  sse= 1513.3
#  ; sseOld = 1513.3
# slope; a = 1.1600000000000001  sse= 1511.1
#  ; sseOld = 1511.1
# slope; a = 1.1700000000000002  sse= 1509.1
#  ; sseOld = 1509.1
# slope; a = 1.1800000000000002  sse= 1507.3
#  ; sseOld = 1507.3
# slope; a = 1.1900000000000002  sse= 1505.6
#  ; sseOld = 1505.6
# slope; a = 1.2000000000000002  sse= 1504.2
#  ; sseOld = 1504.2
# slope; a = 1.2100000000000002  sse= 1503.0
#  ; sseOld = 1503.0
# slope; a = 1.2200000000000002  sse= 1501.9
#  ; sseOld = 1501.9
# slope; a = 1.2300000000000002  sse= 1501.1
#  ; sseOld = 1501.1
# slope; a = 1.2400000000000002  sse= 1500.5
#  ; sseOld = 1500.5
# slope; a = 1.2500000000000002  sse= 1500.1
#  ; sseOld = 1500.1
# slope; a = 1.2600000000000002  sse= 1499.8
#  ; sseOld = 1499.8
# slope; a = 1.2700000000000002  sse= 1499.8
#  ; sseOld = 1499.8
# slope; a = 1.2800000000000002  sse= 1500.0
# Out of while: slope = 1.27 min_sse =  1499.8
# ###############  End of Program  ################
